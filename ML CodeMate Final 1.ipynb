# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/muskansharma//Desktop/ML internship task Feyyns lab/Studentdata (1).csv")

# %%
df.head()
# Out:
#    Unnamed: 0 2.Gender 3. Year of Study 4. Branch  \
# 0           0     Male            Third    CSE/IT
# 1           1   Female           Second      CSIT
# 2           2     Male           Second      CSIT
# 3           3     Male           Second      CSIT
# 4           4     Male           Second      CSIT
#
#   1. Type of Schooling till 10th Grade: 2. Percentage in Class 10th?  \
# 0                      Normal Schooling               >=80% and <90%
# 1               Schooling with Tuitions                       >= 90%
# 2                      Normal Schooling                       >= 90%
# 3                      Normal Schooling               >=70% and <80%
# 4                      Normal Schooling               >=70% and <80%
#
#   3. Location of Class 10th School: 4. Type of Schooling for class 12th:  \
# 0                              Town                     Normal Schooling
# 1                              City              Schooling with Tuitions
# 2                              City               Coaching Based Schools
# 3                              City                     Normal Schooling
# 4                              City                     Normal Schooling
#
#   5. Percentage in Class 12th? 6. Location of Class 12th School:  ...  \
# 0               >=80% and <90%                              Town  ...
# 1                        >=90%                              City  ...
# 2                        >=90%                              City  ...
# 3               >=80% and <90%                              City  ...
# 4               >=80% and <90%                              City  ...
#
#   3. Exposure to Data structure and algorithms? 4. Exposure to GitHub ?  \
# 0                                          Hard                  Medium
# 1                                        Medium                  Medium
# 2                                        Medium                  Medium
# 3                                        Medium                    Easy
# 4                                        Medium                    Hard
#
#   5. Are you associated with any developer Community?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                Yes
#
#   6. Active in developer Communities  \
# 0                      Active Member
# 1                  Moderately active
# 2                    Inactive Member
# 3                  Moderately active
# 4                      Active Member
#
#   7. Participating in Hackathons and other competitions?  \
# 0                                       Participated
# 1                               Not yet participated
# 2                               Not yet participated
# 3                               Not yet participated
# 4                                       Participated
#
#   8. Have you made any Software based projects?  \
# 0                                           Yes
# 1                                           Yes
# 2                                           Yes
# 3                                           Yes
# 4                                           Yes
#
#   9. Have you made any Hardware based project (Arduino, Raspberry Pi, Robots or any other)?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   10. Have you ever pitched any idea? 11. Do you have any additional skills?  \
# 0                                 Yes                    Cultural Activities
# 1                                  No                    Cultural Activities
# 2                                  No              Photography;Video Editing
# 3                                  No                                   None
# 4                                 Yes                                   None
#
#                                       Achievements:
# 0  Scholarships;Hackathons;Research Papers;Projects
# 1                                              None
# 2                                              None
# 3                                              None
# 4           Hackathons;Coding Competitions;Projects
#
# [5 rows x 25 columns]

# %%
#renaming columns for simplification 
df.columns
# Out:
# Index(['Unnamed: 0', '2.Gender', '3. Year of Study', '4. Branch',
#        '1. Type of Schooling till 10th Grade:', '2. Percentage in Class 10th?',
#        '3. Location of Class 10th School:',
#        '4. Type of Schooling for class 12th:', '5. Percentage in Class 12th?',
#        '6. Location of Class 12th School:', '7. Dropped an year after School?',
#        '8. Are you about to become first generation graduate ?',
#        '9. Involved in additional volunteer groups?(NCC,NSS, Social Welfare Groups  or any other)',
#        '1. How many programming languages do you know? ',
#        '2.  Actively involved in Specific technology?',
#        '3. Exposure to Data structure and algorithms?',
#        '4. Exposure to GitHub ?',
#        '5. Are you associated with any developer Community?',
#        '6. Active in developer Communities',
#        '7. Participating in Hackathons and other competitions?',
#        '8. Have you made any Software based projects?',
#        '9. Have you made any Hardware based project (Arduino, Raspberry Pi, Robots or any other)?',
#        '10. Have you ever pitched any idea?',
#        '11. Do you have any additional skills?', 'Achievements:'],
#       dtype='object')

# %%
df=df.rename(columns={'2.Gender':'Gender', '3. Year of Study':'Year of Study', '4. Branch':'Branch',
       '1. Type of Schooling till 10th Grade:':'Type of Schooling <10th', '2. Percentage in Class 10th?':'% in Class 10th',
       '3. Location of Class 10th School:':'Location of Class 10th',
       '4. Type of Schooling for class 12th:':'Type of Schooling 12th', '5. Percentage in Class 12th?':'% in Class 12th',
       '6. Location of Class 12th School:':'Location of Class 12th', '7. Dropped an year after School?':'Dropped 1y after School',
       '8. Are you about to become first generation graduate ?':'Want to be 1st generation graduate',
       '9. Involved in additional volunteer groups?(NCC,NSS, Social Welfare Groups  or any other)':'Involved in additional volunteer',
       '1. How many programming languages do you know? ':'The number of programming languages',
       '2.  Actively involved in Specific technology?':'Involved in specific technology?',
       '3. Exposure to Data structure and algorithms?':'Data structure and algorithms?',
       '4. Exposure to GitHub ?':'Github?',
       '5. Are you associated with any developer Community?':'Associated with any developer Community',
       '6. Active in developer Communities':'Developer Communities',
       '7. Participating in Hackathons and other competitions?':'Hackathons and other competitions',
       '8. Have you made any Software based projects?':'Software based projects',
       '9. Have you made any Hardware based project (Arduino, Raspberry Pi, Robots or any other)?':'Hardware based project',
       '10. Have you ever pitched any idea?':'Pitch',
       '11. Do you have any additional skills?':'Any additional skills'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 25 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               256 non-null    int64
#  1   Gender                                   256 non-null    object
#  2   Year of Study                            256 non-null    object
#  3   Branch                                   256 non-null    object
#  4   Type of Schooling <10th                  256 non-null    object
#  5   % in Class 10th                          256 non-null    object
#  6   Location of Class 10th                   256 non-null    object
#  7   Type of Schooling 12th                   256 non-null    object
#  8   % in Class 12th                          256 non-null    object
#  9   Location of Class 12th                   256 non-null    object
#  10  Dropped 1y after School                  256 non-null    object
#  11  Want to be 1st generation graduate       256 non-null    object
#  12  Involved in additional volunteer         256 non-null    object
#  13  The number of programming languages      256 non-null    object
#  14  Involved in specific technology?         256 non-null    object
#  15  Data structure and algorithms?           256 non-null    object
#  16  Github?                                  256 non-null    object
#  17  Associated with any developer Community  256 non-null    object
#  18  Developer Communities                    216 non-null    object
#  19  Hackathons and other competitions        256 non-null    object
#  20  Software based projects                  256 non-null    object
#  21  Hardware based project                   256 non-null    object
#  22  Pitch                                    256 non-null    object
#  23  Any additional skills                    256 non-null    object
#  24  Achievements:                            256 non-null    object
# dtypes: int64(1), object(24)
# memory usage: 50.1+ KB

# %%
df['Branch'].unique()
# Out:
# array(['CSE/IT', 'CSIT', 'CSE', 'IT', 'CS', 'ECE', 'CSAI', 'EN', 'CSME',
#        'ME', 'CE', 'MCA'], dtype=object)

# %% [markdown]
# #### Renaming all Computer Science Branches to one

# %%
df['Branch'].replace(to_replace=['CSE/IT' ,'CSIT','CSE','IT','CS'],value='CSIT',inplace=True)

# %%
df['Branch'].unique()
# Out:
# array(['CSIT', 'ECE', 'CSAI', 'EN', 'CSME', 'ME', 'CE', 'MCA'],
#       dtype=object)

# %% [markdown]
# #### Handling missing values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                  0
# Gender                                      0
# Year of Study                               0
# Branch                                      0
# Type of Schooling <10th                     0
# % in Class 10th                             0
# Location of Class 10th                      0
# Type of Schooling 12th                      0
# % in Class 12th                             0
# Location of Class 12th                      0
# Dropped 1y after School                     0
# Want to be 1st generation graduate          0
# Involved in additional volunteer            0
# The number of programming languages         0
# Involved in specific technology?            0
# Data structure and algorithms?              0
# Github?                                     0
# Associated with any developer Community     0
# Developer Communities                      40
# Hackathons and other competitions           0
# Software based projects                     0
# Hardware based project                      0
# Pitch                                       0
# Any additional skills                       0
# Achievements:                               0
# dtype: int64

# %%
#treating null values
df.fillna('Inactive Member',inplace=True)

# %%
df['Associated with any developer Community'].value_counts().plot(kind='bar',legend=True)
# Out:
# <AxesSubplot:>

# %%
df['Developer Communities'].value_counts().plot(kind='bar',legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### INFERENCE:
#
#     1. Maximum Students are not associated with any developer community.
#     2. Among the associated members it is eveident that active members are very less that means students are
#        unaware about the importance of a community and need to be more participative.

# %%
def achieve(i):
    if i =='None':
        return 0
    else:
        return 1

# %%
df['Achievements2']=df['Achievements:'].apply(achieve)

# %%
df.head()
# Out:
#    Unnamed: 0  Gender Year of Study Branch  Type of Schooling <10th  \
# 0           0    Male         Third   CSIT         Normal Schooling
# 1           1  Female        Second   CSIT  Schooling with Tuitions
# 2           2    Male        Second   CSIT         Normal Schooling
# 3           3    Male        Second   CSIT         Normal Schooling
# 4           4    Male        Second   CSIT         Normal Schooling
#
#   % in Class 10th Location of Class 10th   Type of Schooling 12th  \
# 0  >=80% and <90%                   Town         Normal Schooling
# 1          >= 90%                   City  Schooling with Tuitions
# 2          >= 90%                   City   Coaching Based Schools
# 3  >=70% and <80%                   City         Normal Schooling
# 4  >=70% and <80%                   City         Normal Schooling
#
#   % in Class 12th Location of Class 12th  ... Github?  \
# 0  >=80% and <90%                   Town  ...  Medium
# 1           >=90%                   City  ...  Medium
# 2           >=90%                   City  ...  Medium
# 3  >=80% and <90%                   City  ...    Easy
# 4  >=80% and <90%                   City  ...    Hard
#
#   Associated with any developer Community Developer Communities  \
# 0                                     Yes         Active Member
# 1                                      No     Moderately active
# 2                                      No       Inactive Member
# 3                                     Yes     Moderately active
# 4                                     Yes         Active Member
#
#   Hackathons and other competitions Software based projects  \
# 0                      Participated                     Yes
# 1              Not yet participated                     Yes
# 2              Not yet participated                     Yes
# 3              Not yet participated                     Yes
# 4                      Participated                     Yes
#
#   Hardware based project Pitch      Any additional skills  \
# 0                     No   Yes        Cultural Activities
# 1                     No    No        Cultural Activities
# 2                     No    No  Photography;Video Editing
# 3                    Yes    No                       None
# 4                     No   Yes                       None
#
#                                       Achievements: Achievements2
# 0  Scholarships;Hackathons;Research Papers;Projects             1
# 1                                              None             0
# 2                                              None             0
# 3                                              None             0
# 4           Hackathons;Coding Competitions;Projects             1
#
# [5 rows x 26 columns]

# %%
cat=['Gender', 'Year of Study', 'Branch', 'Type of Schooling <10th',
       '% in Class 10th', 'Location of Class 10th', 'Type of Schooling 12th',
       '% in Class 12th', 'Location of Class 12th', 'Dropped 1y after School',
       'Want to be 1st generation graduate',
       'Involved in additional volunteer',
       'The number of programming languages',
       'Involved in specific technology?', 'Data structure and algorithms?',
       'Github?', 'Associated with any developer Community',
       'Developer Communities', 'Hackathons and other competitions',
       'Software based projects', 'Hardware based project', 'Pitch',
       'Any additional skills']

# %% [markdown]
# #### 1) Non achievement and achievement

# %%
df['Achievements2'].value_counts().plot(kind='bar',legend=True);

# %% [markdown]
# #### INFERENCE:
#     It is evident and positive observation that there are more number of students who have achieved something in           coding domain.
#     Though there is not huge difference between the number of students who have achievements and others who do not.

# %% [markdown]
# #### 2) Histplot by Non achievement and achievement

# %%
fig = plt.figure(figsize=(20,30))

for i in range(len(cat)):
    plt.subplot(8,3,i+1)
    sns.histplot(data=df,y=df[cat[i]],hue=df['Achievements2'])
    
plt.tight_layout()
plt.show()

# %%
df['Hackathons and other competitions'].value_counts().plot(kind='bar',legend=True);

# %% [markdown]
# #### INFERENCE:
#     There is a need to inculcate coding competitions among students in order to increase their skills and make them aware about where they stand when compared to people of same domain.

# %%
df['Github?'].value_counts().plot(kind='bar',legend=True);

# %%
df['Data structure and algorithms?'].value_counts().plot(kind='pie',legend=True);

# %% [markdown]
# #### INFERENCE:
#     It is evident that students already know about DSA just their expertise differ.

# %%
Dsa_Hackathon=df.groupby(['Hackathons and other competitions','Data structure and algorithms?']).size().unstack()

# %%
Dsa_Hackathon.plot.bar(stacked=True, figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Hackathons and other competitions'>

# %% [markdown]
# #### INFERENCE:
#     It is observed that students who haven't participated in Hackathons still have intermediate knowledge of DSA,
#     they just haven't put it to practise.

# %%
Git_Dev=df.groupby(['Associated with any developer Community','Github?']).size().unstack()

# %%
Git_Dev.plot.bar(stacked=True, figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Associated with any developer Community'>

# %% [markdown]
# #### INFERENCE:
# It's observed that the more students have knowledge of Github but they are still not part of any commmunity.

# %%
#Reading the csv file using pandas
data = pd.read_csv('/Users/muskansharma/Documents/Most Popular Programming Languages from 2004 to 2020.csv')

#Convering the date to Datetime data type
data['Date'] = pd.to_datetime(data['Date'])

#Setting date as index
data.set_index('Date', inplace = True)

#Displying first few lines of the dataset
data.head()
# Out:
#             Abap   Ada  C/C++    C#  Cobol  Dart  Delphi   Go  Groovy  \
# Date
# 2004-07-01  0.36  0.38   9.97  4.86   0.44   0.0    2.89  0.0    0.03
# 2004-08-01  0.37  0.38   9.65  5.20   0.48   0.0    2.78  0.0    0.07
# 2004-09-01  0.43  0.43   9.46  5.29   0.53   0.0    2.77  0.0    0.08
# 2004-10-01  0.42  0.39   9.16  5.43   0.55   0.0    2.84  0.0    0.09
# 2004-11-01  0.39  0.39   9.37  5.40   0.57   0.0    2.85  0.0    0.08
#
#             Haskell  ...    PHP  Python     R  Ruby  Rust  Scala  Swift  \
# Date                 ...
# 2004-07-01     0.23  ...  18.77    2.60  0.40  0.35  0.08   0.03    0.0
# 2004-08-01     0.21  ...  18.88    2.75  0.42  0.41  0.10   0.03    0.0
# 2004-09-01     0.22  ...  18.93    2.84  0.42  0.43  0.11   0.03    0.0
# 2004-10-01     0.21  ...  18.92    2.99  0.43  0.47  0.12   0.04    0.0
# 2004-11-01     0.25  ...  19.02    2.93  0.43  0.46  0.14   0.04    0.0
#
#             TypeScript   VBA  Visual Basic
# Date
# 2004-07-01         0.0  1.49          8.84
# 2004-08-01         0.0  1.52          8.96
# 2004-09-01         0.0  1.62          8.82
# 2004-10-01         0.0  1.65          8.70
# 2004-11-01         0.0  1.55          8.50
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Looking for null values

# %%
data.sum().isnull()
# Out:
# Abap            False
# Ada             False
# C/C++           False
# C#              False
# Cobol           False
# Dart            False
# Delphi          False
# Go              False
# Groovy          False
# Haskell         False
# Julia           False
# Kotlin          False
# Java            False
# Javascript      False
# Lua             False
# Matlab          False
# Objective-C     False
# Perl            False
# PHP             False
# Python          False
# R               False
# Ruby            False
# Rust            False
# Scala           False
# Swift           False
# TypeScript      False
# VBA             False
# Visual Basic    False
# dtype: bool

# %% [markdown]
# We can see that there are no missing values in the data.
# Now, we can move to the visualization step.

# %%
data.describe()
# Out:
#              Abap         Ada       C/C++          C#       Cobol        Dart  \
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean     0.498814    0.295928    8.412010    7.647268    0.383969    0.100825
# std      0.102133    0.079515    1.778675    1.309938    0.073387    0.116980
# min      0.320000    0.170000    5.720000    4.860000    0.250000    0.000000
# 25%      0.400000    0.230000    7.630000    6.600000    0.320000    0.000000
# 50%      0.500000    0.285000    8.025000    7.355000    0.380000    0.110000
# 75%      0.580000    0.350000    9.152500    8.927500    0.440000    0.130000
# max      0.730000    0.540000   12.980000   10.000000    0.580000    0.570000
#
#            Delphi          Go      Groovy     Haskell  ...         PHP  \
# count  194.000000  194.000000  194.000000  194.000000  ...  194.000000
# mean     1.098299    0.272371    0.330722    0.301598  ...   14.505825
# std      0.764734    0.395568    0.139438    0.038870  ...    4.727871
# min      0.220000    0.000000    0.030000    0.210000  ...    5.780000
# 25%      0.390000    0.000000    0.252500    0.280000  ...   10.917500
# 50%      0.890000    0.065000    0.370000    0.300000  ...   15.025000
# 75%      1.737500    0.365000    0.447500    0.320000  ...   19.205000
# max      2.890000    1.390000    0.520000    0.400000  ...   20.320000
#
#            Python           R        Ruby        Rust       Scala       Swift  \
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean    11.063093    2.029691    2.160670    0.206959    0.528299    1.055103
# std      7.989862    1.311785    0.694323    0.179043    0.442681    1.388318
# min      2.600000    0.390000    0.350000    0.050000    0.010000    0.000000
# 25%      5.147500    0.835000    1.667500    0.080000    0.130000    0.000000
# 50%      8.155000    1.730000    2.510000    0.120000    0.405000    0.000000
# 75%     13.685000    3.407500    2.660000    0.302500    1.000000    2.460000
# max     31.880000    4.190000    3.010000    0.910000    1.350000    3.590000
#
#        TypeScript         VBA  Visual Basic
# count  194.000000  194.000000    194.000000
# mean     0.405309    1.701701      3.857062
# std      0.640866    0.323910      2.192946
# min      0.000000    1.190000      0.820000
# 25%      0.000000    1.460000      1.662500
# 50%      0.010000    1.630000      3.880000
# 75%      0.595000    1.832500      5.357500
# max      1.960000    2.550000      8.960000
#
# [8 rows x 28 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 194 entries, 2004-07-01 to 2020-08-01
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Abap          194 non-null    float64
#  1   Ada           194 non-null    float64
#  2   C/C++         194 non-null    float64
#  3   C#            194 non-null    float64
#  4   Cobol         194 non-null    float64
#  5   Dart          194 non-null    float64
#  6   Delphi        194 non-null    float64
#  7   Go            194 non-null    float64
#  8   Groovy        194 non-null    float64
#  9   Haskell       194 non-null    float64
#  10  Julia         194 non-null    float64
#  11  Kotlin        194 non-null    float64
#  12  Java          194 non-null    float64
#  13  Javascript    194 non-null    float64
#  14  Lua           194 non-null    float64
#  15  Matlab        194 non-null    float64
#  16  Objective-C   194 non-null    float64
#  17  Perl          194 non-null    float64
#  18  PHP           194 non-null    float64
#  19  Python        194 non-null    float64
#  20  R             194 non-null    float64
#  21  Ruby          194 non-null    float64
#  22  Rust          194 non-null    float64
#  23  Scala         194 non-null    float64
#  24  Swift         194 non-null    float64
#  25  TypeScript    194 non-null    float64
#  26  VBA           194 non-null    float64
#  27  Visual Basic  194 non-null    float64
# dtypes: float64(28)
# memory usage: 44.0 KB

# %% [markdown]
# For visualization I'm including only those programming languages whose mean value is greater than 2.5.
# And I'm doing this using the result as boolean mask.

# %%
mask = data.mean() > 2.5

data = data.loc[:, mask]

clms = data.columns.tolist()
clms
# Out:
# ['C/C++',
#  'C#',
#  'Java',
#  'Javascript',
#  'Matlab',
#  'Objective-C',
#  'Perl',
#  'PHP',
#  'Python',
#  'Visual Basic']

# %% [markdown]
# The above clms list showing our top 10 programming languages.

# %% [markdown]
# ### Visualization

# %%
 
plt.figure(figsize = (15, 8))
sns.set(style = 'dark')

for language in clms:
    sns.lineplot(x = data.index, y = data[language], label = language)

plt.ylabel('Popularity', fontsize = 12)
plt.xlabel('Year', fontsize = 12)
plt.title('Popular Prgramming Languages', fontsize = 20)
plt.legend(loc = 2)
plt.yticks(fontsize = 10)
plt.xticks(rotation = 45, fontsize = 10)
plt.tight_layout()
plt.show()

# %%
import gc

from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv('/Users/muskansharma/Documents/edtech_data.csv')
data1.head()
# Out:
#                           client_id                           user_id  \
# 0  2989400374e8abf2c4ac8921531cd1c0  92cc220d5171deb66e947d5b4ffce8bd
# 1  c8bce51779d3f746baaf2f59ddef69cd  80cf7575a4dc3a3a8cb30e3262d23e19
# 2  a6bad682ac10999865570bee0e11b9f6  3b671290e690217ce17052c9c52afa31
# 3  b85c31b416b405dd9b9498bdde703f4e  03e4d2186bc5231cd7f302ac76e1de76
# 4  93c44d3b5d850f60ada1faf9db83b7f7  ec8a79f01156b3c82a27ca947f49d319
#
#   first_trial_appointment_date first_payment_date       os           tutor  \
# 0                          NaN                NaN  Android             NaN
# 1                          NaN                NaN  Windows  I am doing now
# 2                          NaN                NaN  Android              No
# 3                          NaN                NaN      iOS             NaN
# 4                          NaN                NaN  Android              No
#
#        job  task_class  average_score  homework_done  paywall_paid  \
# 0      NaN         6.0      80.222222              9         False
# 1       IT        11.0      98.250000              4         False
# 2      NaN         5.0      68.000000              1         False
# 3      NaN         7.0      78.571429              7         False
# 4  Finance         6.0      92.000000              4         False
#
#   school_name  desktop_enter  nps_score  add_homework_done         call_date  \
# 0     Unknown           True        NaN                  0  2020-09-14 13:29
# 1     Unknown           True        NaN                  0  2020-07-16 15:03
# 2     Unknown           True        NaN                  0  2020-08-25 10:03
# 3     Unknown           True        NaN                  0  2020-08-13 14:41
# 4     Unknown           True        NaN                  0  2020-08-27 13:23
#
#    first_visit_date region  is_big_city
# 0  2020-04-22 09:48    NaN         True
# 1  2020-04-24 17:29    NaN         True
# 2  2020-04-15 10:10    NaN         True
# 3  2020-04-28 14:04    NaN         True
# 4  2020-04-28 11:26    NaN         True

# %% [markdown]
# ### Fast EDA & Feature preparation

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124517 entries, 0 to 124516
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   client_id                     124517 non-null  object
#  1   user_id                       124517 non-null  object
#  2   first_trial_appointment_date  20657 non-null   object
#  3   first_payment_date            921 non-null     object
#  4   os                            124501 non-null  object
#  5   tutor                         48697 non-null   object
#  6   job                           38608 non-null   object
#  7   task_class                    123212 non-null  float64
#  8   average_score                 121500 non-null  float64
#  9   homework_done                 124517 non-null  int64
#  10  paywall_paid                  124517 non-null  bool
#  11  school_name                   124517 non-null  object
#  12  desktop_enter                 124517 non-null  bool
#  13  nps_score                     275 non-null     float64
#  14  add_homework_done             124517 non-null  int64
#  15  call_date                     124517 non-null  object
#  16  first_visit_date              124517 non-null  object
#  17  region                        12142 non-null   object
#  18  is_big_city                   124517 non-null  bool
# dtypes: bool(3), float64(3), int64(2), object(11)
# memory usage: 15.6+ MB

# %%
bool_cols = ['paywall_paid', 'desktop_enter', 'is_big_city']
for col in bool_cols:
    data1[col] = data1[col].astype(int)

# %%
date_cols = ['first_trial_appointment_date', 'first_payment_date',
             'call_date', 'first_visit_date'
            ]
for col in date_cols:
    data1[col] = pd.to_datetime(data1[col])

# %%
fill_cols = ['os', 'tutor', 'job', 'school_name', 'region']
data1[fill_cols] = data1[fill_cols].fillna('Unknown')

# %% [markdown]
# ### Dedublication

# %%
df_ = data1.groupby('user_id').agg('count').reset_index()[['user_id', 'client_id']]
#df_['client_id'] = df_df['client_id']
df_[df_['client_id'] > 1].head()
# Out:
#                               user_id  client_id
# 15   000796759b25145e0dcb8a0fad33d801          2
# 20   000c159a37f9e587091fed0d69fa4b2c          2
# 48   001b9da631dbcb7ac11a525a48a61aa6          2
# 122  004626f806f715350ea69fd9b50787bf          2
# 182  00674f08b030c10c0230181f0ab31322          2

# %%
data1[data1['user_id'] == '000796759b25145e0dcb8a0fad33d801']
# Out:
#                               client_id                           user_id  \
# 80530  0f33dd5b37dc72eb567ca7e3eac8b10a  000796759b25145e0dcb8a0fad33d801
# 96771  0f33dd5b37dc72eb567ca7e3eac8b10a  000796759b25145e0dcb8a0fad33d801
#
#       first_trial_appointment_date first_payment_date       os    tutor  \
# 80530          2020-09-01 15:32:00                NaT  Android  Earlier
# 96771          2020-09-01 15:34:00                NaT  Android  Earlier
#
#             job  task_class  average_score  homework_done  paywall_paid  \
# 80530  Medicine         5.0           81.6              5             0
# 96771  Medicine         5.0           81.6              5             0
#
#       school_name  desktop_enter  nps_score  add_homework_done  \
# 80530     Unknown              1        NaN                  0
# 96771     Unknown              1        NaN                  0
#
#                 call_date    first_visit_date   region  is_big_city
# 80530 2020-08-18 14:53:00 2020-04-28 13:28:00  Unknown            1
# 96771 2020-08-18 14:53:00 2020-04-28 13:28:00  Unknown            1

# %%
data1[data1['user_id'] == 'ffe90ad2bf13647860b4480aaba79e81']
# Out:
#                                client_id                           user_id  \
# 51690   d6d7350ff1cee919c7066d5423426271  ffe90ad2bf13647860b4480aaba79e81
# 107013  d6d7350ff1cee919c7066d5423426271  ffe90ad2bf13647860b4480aaba79e81
#
#        first_trial_appointment_date first_payment_date       os  \
# 51690           2020-07-30 13:37:00                NaT  Android
# 107013          2020-07-30 13:39:00                NaT  Android
#
#                  tutor      job  task_class  average_score  homework_done  \
# 51690   I am doing now  Unknown         7.0           62.1             11
# 107013  I am doing now  Unknown         7.0           62.1             11
#
#         paywall_paid school_name  desktop_enter  nps_score  add_homework_done  \
# 51690              0     Unknown              1        NaN                  0
# 107013             0     Unknown              1        NaN                  0
#
#                  call_date    first_visit_date   region  is_big_city
# 51690  2020-07-27 13:55:00 2020-05-07 20:16:00  Unknown            1
# 107013 2020-07-27 13:55:00 2020-05-07 20:16:00  Unknown            1

# %%
data1[data1['user_id'] == 'ffad160245d011e860b8d2576d06a7a1']
# Out:
#                               client_id                           user_id  \
# 4814   f17a1cd3037402d9e783a53e62986f4f  ffad160245d011e860b8d2576d06a7a1
# 91574  f17a1cd3037402d9e783a53e62986f4f  ffad160245d011e860b8d2576d06a7a1
#
#       first_trial_appointment_date first_payment_date   os           tutor  \
# 4814           2020-06-26 11:57:00                NaT  iOS  I am doing now
# 91574                          NaT                NaT  iOS  I am doing now
#
#            job  task_class  average_score  homework_done  paywall_paid  \
# 4814   Finance         6.0      83.333333              3             0
# 91574  Finance         6.0      83.333333              3             0
#
#       school_name  desktop_enter  nps_score  add_homework_done  \
# 4814      Unknown              0        NaN                  0
# 91574     Unknown              0        NaN                  0
#
#                 call_date    first_visit_date            region  is_big_city
# 4814  2020-06-23 10:51:00 2020-05-08 10:17:00  Saint Petersburg            1
# 91574 2020-06-23 10:51:00 2020-05-08 10:17:00  Saint Petersburg            1

# %%
df_ = data1.groupby('user_id').agg({
    'first_trial_appointment_date': np.max,
    'first_payment_date': np.max,
    'os': np.max,
    'tutor': np.max,
    'job': np.max,
    'task_class': np.max,
    'average_score': np.max,
    'homework_done': np.max,
    'paywall_paid': np.max,
    'school_name': np.max,
    'desktop_enter': np.max,
    'nps_score': np.max,
    'add_homework_done': np.max,
    'call_date': np.max,
    'first_visit_date': np.max,
    'region': np.max,
    'is_big_city': np.max,
}).reset_index()

# %%
df_[df_['user_id'] == 'ffad160245d011e860b8d2576d06a7a1']
# Out:
#                                  user_id first_trial_appointment_date  \
# 118420  ffad160245d011e860b8d2576d06a7a1          2020-06-26 11:57:00
#
#        first_payment_date   os           tutor      job  task_class  \
# 118420                NaT  iOS  I am doing now  Finance         6.0
#
#         average_score  homework_done  paywall_paid school_name  desktop_enter  \
# 118420      83.333333              3             0     Unknown              0
#
#         nps_score  add_homework_done           call_date    first_visit_date  \
# 118420        NaN                  0 2020-06-23 10:51:00 2020-05-08 10:17:00
#
#                   region  is_big_city
# 118420  Saint Petersburg            1

# %%
data1 = df_
del df_
gc.collect();

# %%
assert data1.shape[0] == data1.user_id.nunique(), 'Bad Dedublication'

# %% [markdown]
# ### Correlation

# %%
df_corr = data1.corr()
# plot the heatmap and annotation on it
fig, ax = plt.subplots(figsize=(18,18))
sns.heatmap(df_corr, xticklabels=df_corr.columns, yticklabels=df_corr.columns, annot=True, ax=ax);

# %% [markdown]
# ### Categorical columns

# %%
data1.groupby('os').agg({'user_id': ['count'], 
    'homework_done': [np.mean], 'add_homework_done': [np.mean], 
    'task_class': [np.mean], 'average_score': [np.mean],                  
    'nps_score': [np.mean], 'paywall_paid': [np.mean],
    'desktop_enter': [np.mean],
})
# Out:
#         user_id homework_done add_homework_done task_class average_score  \
#           count          mean              mean       mean          mean
# os
# Android   42476      3.647307          0.114935   6.664719     76.725451
# Linux        44      3.590909          0.159091   6.558140     72.910613
# Mac OS     1035      3.477295          0.261836   6.646199     81.151649
# Solaris       1      2.000000          0.000000   5.000000     95.500000
# Ubuntu       12      2.250000          0.000000   7.166667     87.136364
# Unknown      15      1.133333          0.000000   7.000000     78.490909
# Windows   22244      3.211698          0.088428   6.767658     78.909539
# iOS       52737      3.454558          0.110776   6.855201     76.834572
#
#         nps_score paywall_paid desktop_enter
#              mean         mean          mean
# os
# Android  6.794393     0.000024      0.802124
# Linux         NaN     0.000000      1.000000
# Mac OS   1.000000     0.000000      0.998068
# Solaris       NaN     0.000000      1.000000
# Ubuntu        NaN     0.000000      1.000000
# Unknown       NaN     0.000000      0.200000
# Windows  6.764706     0.000135      0.999011
# iOS      6.860000     0.000076      0.773290

# %%
data1.groupby('tutor').agg({'user_id': ['count'], 
    'homework_done': [np.mean], 'add_homework_done': [np.mean], 
    'task_class': [np.mean], 'average_score': [np.mean],                  
    'nps_score': [np.mean], 'paywall_paid': [np.mean],
    'desktop_enter': [np.mean],
})
# Out:
#                user_id homework_done add_homework_done task_class  \
#                  count          mean              mean       mean
# tutor
# Earlier          19074      3.885918          0.113243   7.189572
# I am doing now   14167      3.869274          0.234206   7.280037
# No               12155      3.982641          0.131222   6.429031
# Unknown          73168      3.211855          0.080582   6.617565
#
#                average_score nps_score paywall_paid desktop_enter
#                         mean      mean         mean          mean
# tutor
# Earlier            76.182943  6.750000     0.000210      0.824526
# I am doing now     79.451714  6.881356     0.000071      0.848168
# No                 77.928733  7.538462     0.000000      0.826244
# Unknown            76.952221  6.611111     0.000041      0.825238

# %%
data1.groupby('job').agg({'user_id': ['count'], 
    'homework_done': [np.mean], 'add_homework_done': [np.mean], 
    'task_class': [np.mean], 'average_score': [np.mean],                  
    'nps_score': [np.mean], 'paywall_paid': [np.mean],
    'desktop_enter': [np.mean],
})
# Out:
#           user_id homework_done add_homework_done task_class average_score  \
#             count          mean              mean       mean          mean
# job
# Education    7150      3.792308          0.068531   7.148498     76.015699
# Finance     10680      4.071816          0.298596   7.155770     77.341742
# IT           6374      3.823031          0.128961   6.960387     80.015871
# Medicine     8513      3.951016          0.176201   6.825675     77.054784
# Science      3278      3.776083          0.083893   7.089026     79.202118
# Unknown     82569      3.286548          0.081059   6.652572     77.041580
#
#           nps_score paywall_paid desktop_enter
#                mean         mean          mean
# job
# Education  7.000000     0.000000      0.808531
# Finance    6.000000     0.000000      0.816948
# IT         5.789474     0.000314      0.879667
# Medicine   7.454545     0.000117      0.802890
# Science    7.750000     0.000305      0.848078
# Unknown    6.836601     0.000048      0.828870

# %%
data1.groupby('is_big_city').agg({'user_id': ['count'], 
    'homework_done': [np.mean], 'add_homework_done': [np.mean], 
    'task_class': [np.mean], 'average_score': [np.mean],                  
    'nps_score': [np.mean], 'paywall_paid': [np.mean],
    'desktop_enter': [np.mean],
})
# Out:
#             user_id homework_done add_homework_done task_class average_score  \
#               count          mean              mean       mean          mean
# is_big_city
# 0             19623      3.512562          0.181929   6.917082     75.764434
# 1             98941      3.470988          0.094996   6.739755     77.512135
#
#             nps_score paywall_paid desktop_enter
#                  mean         mean          mean
# is_big_city
# 0            5.307692     0.000102      0.798298
# 1            6.957082     0.000061      0.833850

# %%
data1.groupby('region').agg({'user_id': ['count'], 
    'homework_done': [np.mean], 'add_homework_done': [np.mean], 
    'task_class': [np.mean], 'average_score': [np.mean],                  
    'nps_score': [np.mean], 'paywall_paid': [np.mean],
    'desktop_enter': [np.mean],
})
# Out:
#                           user_id homework_done add_homework_done task_class  \
#                             count          mean              mean       mean
# region
# Amur Region                     1     10.000000          0.000000   5.000000
# Astrakhan Region                1      1.000000          0.000000   9.000000
# Chelyabinsk Region            182      3.071429          0.043956   7.426966
# Chuvash Republic                1      3.000000          0.000000   9.000000
# Kaliningrad Region              1      8.000000          0.000000  11.000000
# Kemerovo Region                 2     11.500000          0.000000   8.000000
# Krasnodar Territory            19    122.842105        118.000000   6.684211
# Krasnoyarsk Territory         356      3.238764          0.095506   7.060172
# Leningrad Region                8      5.250000          0.000000   6.625000
# Moscow                       3960      3.501515          0.059343   6.988494
# Moscow Region                 843      4.231317          0.109134   7.008333
# Nizhny Novgorod Region        218      3.174312          0.027523   6.851163
# Novosibirsk Region            385      3.800000          0.103896   7.489529
# Omsk Region                   199      3.849246          0.070352   7.137755
# Orenburg Region                 1      1.000000          0.000000   5.000000
# Other                           1      1.000000          0.000000   9.000000
# Perm Territory                142      3.471831          0.021127   7.264706
# Primorye Territory              1      4.000000          0.000000  11.000000
# Republic of Bashkortostan     394      4.378173          0.312183   7.226804
# Republic of Mordovia            1      1.000000          0.000000   5.000000
# Republic of Tatarstan         257      2.879377          0.031128   6.902724
# Rostov Region                 250      3.600000          0.044000   6.843621
# Saint Petersburg             2617      3.674818          0.102407   7.409830
# Samara Region                 427      3.161593          0.166276   7.229858
# Stavropol Territory             1      3.000000          1.000000  11.000000
# Sverdlovsk Region             664      3.682229          0.097892   6.966616
# Tula Region                     2      5.000000          0.000000   5.500000
# Ulyanovsk Region                1      1.000000          0.000000   9.000000
# Unknown                    107290      3.443406          0.090642   6.729661
# Volgograd Region              188      3.069149          0.101064   7.207447
# Voronezh Region               150      3.673333          0.026667   7.776224
# Yaroslavl Region                1      1.000000          0.000000   5.000000
#
#                           average_score  nps_score paywall_paid desktop_enter
#                                    mean       mean         mean          mean
# region
# Amur Region                   95.100000        NaN     0.000000      1.000000
# Astrakhan Region              81.000000        NaN     0.000000      1.000000
# Chelyabinsk Region            73.965857  10.000000     0.000000      0.890110
# Chuvash Republic              95.000000        NaN     0.000000      1.000000
# Kaliningrad Region            91.142857        NaN     0.000000      1.000000
# Kemerovo Region               86.428571        NaN     0.000000      0.500000
# Krasnodar Territory           70.890059        NaN     0.000000      0.894737
# Krasnoyarsk Territory         75.202518   7.000000     0.000000      0.806180
# Leningrad Region              80.544345        NaN     0.000000      1.000000
# Moscow                        78.335211   7.555556     0.000000      0.839394
# Moscow Region                 79.307417   6.333333     0.000000      0.832740
# Nizhny Novgorod Region        79.464404        NaN     0.000000      0.834862
# Novosibirsk Region            75.888825   8.000000     0.000000      0.838961
# Omsk Region                   75.828493        NaN     0.000000      0.869347
# Orenburg Region               57.000000        NaN     0.000000      1.000000
# Other                         80.000000        NaN     0.000000      1.000000
# Perm Territory                73.221844        NaN     0.000000      0.823944
# Primorye Territory            58.750000        NaN     0.000000      1.000000
# Republic of Bashkortostan     76.482495        NaN     0.000000      0.781726
# Republic of Mordovia          95.000000        NaN     0.000000      0.000000
# Republic of Tatarstan         77.383906        NaN     0.000000      0.774319
# Rostov Region                 73.363326        NaN     0.000000      0.812000
# Saint Petersburg              78.828184   5.600000     0.000000      0.840657
# Samara Region                 77.544223   1.000000     0.000000      0.803279
# Stavropol Territory           81.666667        NaN     0.000000      1.000000
# Sverdlovsk Region             76.725978   5.500000     0.000000      0.862952
# Tula Region                   82.047619        NaN     0.000000      0.500000
# Ulyanovsk Region              53.000000        NaN     0.000000      0.000000
# Unknown                       77.165610   6.828194     0.000075      0.827225
# Volgograd Region              80.181104        NaN     0.000000      0.813830
# Voronezh Region               73.980515   9.000000     0.000000      0.860000
# Yaroslavl Region              77.000000        NaN     0.000000      1.000000

# %% [markdown]
# ### Outliers

# %%
data1[(data1['region'] == 'Krasnodar Territory') & (data1['homework_done'] > 200)]
# Out:
#                                 user_id first_trial_appointment_date  \
# 51715  7045204b7a81b991420aeab6e4e4c288          2020-09-01 18:29:00
#
#        first_payment_date   os           tutor      job  task_class  \
# 51715 2020-09-03 22:20:00  iOS  I am doing now  Finance         7.0
#
#        average_score  homework_done  paywall_paid school_name  desktop_enter  \
# 51715      69.192497           2275             0     Unknown              1
#
#        nps_score  add_homework_done           call_date    first_visit_date  \
# 51715        NaN               2242 2020-08-28 11:58:00 2020-04-17 16:37:00
#
#                     region  is_big_city
# 51715  Krasnodar Territory            0

# %%
data1[data1['homework_done'] > 200]['user_id'].count()
# Out:
# 8

# %%
data1 = data1[data1['homework_done'] < 200]

# %% [markdown]
# ### Distributions

# %%
data1['task_class'].hist(bins=10);

# %%
data1[data1['homework_done'] < 50]['homework_done'].hist(bins=50);

# %%
data1[data1['add_homework_done'] < 10]['add_homework_done'].hist(bins=10);

# %%
data1['average_score'].hist(bins=50);

# %%
sns.pairplot(data1);
